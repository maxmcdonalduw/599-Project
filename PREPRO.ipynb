# %% [markdown]
# # Task List
#
# This file should be a mix of code and text explaining what the code does
#
# 1. Import the data
# 2. Select the variables we're keeping
# 3. Change name of variables so that it's interpretable
# 4. Properly code missing values
# 5. Check for pattern of missing values (imputation necessary?)
# 6. Check binary variables so that they're 0/1 coded
# 7. Save as .csv file to repo

# %% [markdown]
# This imports pandas and the data set.

# %%
import pandas as pd
Survey='https://github.com/arsell/599-Project/blob/master/raw/HNBR62FL.DTA?raw=true'
DHS=pd.read_stata(Survey)

# %% [markdown]
# This creates a dataframe with the variables from the data that will be used in our analysis.

# %%
DF=pd.DataFrame(DHS[['caseid', 'v133', 'v012', 'v130', 'v024', 'v190', 'v191','v025']])

# %% [markdown]
# This renames the variables.

# %%
DF.columns=['CASEID',
            'Education in single years',
           'Respondent\'s current age', 
           'Religion', 
           'Region', 
           'Wealth index categorical', 
           'Wealth index decimal',
           'Type of residence']

# %%
DF.head(20)
# Out:
#      CASEID Education in single years  Respondent's current age  \
# 0   1 21  1                         6                        40
# 1   1 21  1                         6                        40
# 2   1 21  1                         6                        40
# 3   1 21  1                         6                        40
# 4   1 21  1                         6                        40
# 5   1 21  1                         6                        40
# 6   1 21  1                         6                        40
# 7   1 21  9                         6                        21
# 8   1 21  9                         6                        21
# 9   1 21 13                         4                        36
# 10  1 21 13                         4                        36
# 11  1 21 13                         4                        36
# 12  1 21 13                         4                        36
# 13  1 41  2                         0                        28
# 14  1 41  2                         0                        28
# 15  1 41  2                         0                        28
# 16  1 41  6                         3                        47
# 17  1 41  6                         3                        47
# 18  1 41  6                         3                        47
# 19  1 41  6                         3                        47
#
#                     Religion     Region Wealth index categorical  \
# 0   Evangelical / Protestant  Atl?ntida                   Richer
# 1   Evangelical / Protestant  Atl?ntida                   Richer
# 2   Evangelical / Protestant  Atl?ntida                   Richer
# 3   Evangelical / Protestant  Atl?ntida                   Richer
# 4   Evangelical / Protestant  Atl?ntida                   Richer
# 5   Evangelical / Protestant  Atl?ntida                   Richer
# 6   Evangelical / Protestant  Atl?ntida                   Richer
# 7   Evangelical / Protestant  Atl?ntida                   Richer
# 8   Evangelical / Protestant  Atl?ntida                   Richer
# 9   Evangelical / Protestant  Atl?ntida                   Richer
# 10  Evangelical / Protestant  Atl?ntida                   Richer
# 11  Evangelical / Protestant  Atl?ntida                   Richer
# 12  Evangelical / Protestant  Atl?ntida                   Richer
# 13  Evangelical / Protestant  Atl?ntida                   Poorer
# 14  Evangelical / Protestant  Atl?ntida                   Poorer
# 15  Evangelical / Protestant  Atl?ntida                   Poorer
# 16  Evangelical / Protestant  Atl?ntida                   Poorer
# 17  Evangelical / Protestant  Atl?ntida                   Poorer
# 18  Evangelical / Protestant  Atl?ntida                   Poorer
# 19  Evangelical / Protestant  Atl?ntida                   Poorer
#
#     Wealth index decimal Type of residence
# 0                  72182             Urban
# 1                  72182             Urban
# 2                  72182             Urban
# 3                  72182             Urban
# 4                  72182             Urban
# 5                  72182             Urban
# 6                  72182             Urban
# 7                  72182             Urban
# 8                  72182             Urban
# 9                  72182             Urban
# 10                 72182             Urban
# 11                 72182             Urban
# 12                 72182             Urban
# 13                -87333             Urban
# 14                -87333             Urban
# 15                -87333             Urban
# 16                -87333             Urban
# 17                -87333             Urban
# 18                -87333             Urban
# 19                -87333             Urban
